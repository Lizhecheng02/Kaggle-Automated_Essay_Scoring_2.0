# %%
import kagglehub

# %%
for i in range(10):
    handle = 'bianshengtao/deberta-v3-large/pytorch/deberta-v3-large_AES2_v2_cv-0.805_fold_{}'.format(i)
    local_model_dir = '/ai/users/bst/competition/outputs/deberta-v3-large_AES2_fold_{}_v2'.format(i)
    kagglehub.model_upload(handle, local_model_dir)
# Out:
# Starting upload for file config.json
# Uploading:   0%|          | 0.00/993 [00:04<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 handle = 'bianshengtao/deberta-v3-large/pytorch/deberta-v3-large_AES2_v2_cv-0.805_fold_{}'.format(i)
#       3 local_model_dir = '/ai/users/bst/competition/outputs/deberta-v3-large_AES2_fold_{}_v2'.format(i)
# ----> 4 kagglehub.model_upload(handle, local_model_dir)
#
# File ~/.local/lib/python3.8/site-packages/kagglehub/models.py:50, in model_upload(handle, local_model_dir, license_name, version_notes)
#      47 create_model_if_missing(h.owner, h.model)
#      49 # Upload the model files to GCS
# ---> 50 tokens = upload_files_and_directories(local_model_dir, "model")
#      52 # Create a model instance if it doesn't exist, and create a new instance version if an instance exists
# ...
